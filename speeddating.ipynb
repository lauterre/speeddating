# %%
import pandas as pd
pd.set_option("display.max_columns", None)
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("D:/Downloads/speeddating.csv")

# %%
df['samerace'] = df['samerace'].str.replace('[^0-9]', '', regex=True).astype('int64')
df['decision'] = df['decision'].str.replace('[^0-9]', '', regex=True).astype('int64')
df['decision_o'] = df['decision_o'].str.replace('[^0-9]', '', regex=True).astype('int64')

# %%
df.head()
# Out:
#   has_null  wave     gender   age  age_o  d_age   d_d_age
# 0      b''   1.0  b'female'  21.0   27.0    6.0  b'[4-6]'  \
# 1      b''   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 2      b''   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 3      b''   1.0  b'female'  21.0   23.0    2.0  b'[2-3]'
# 4      b''   1.0  b'female'  21.0   24.0    3.0  b'[2-3]'
#
#                                        race
# 0  b'Asian/Pacific Islander/Asian-American'  \
# 1  b'Asian/Pacific Islander/Asian-American'
# 2  b'Asian/Pacific Islander/Asian-American'
# 3  b'Asian/Pacific Islander/Asian-American'
# 4  b'Asian/Pacific Islander/Asian-American'
#
#                                      race_o  samerace  importance_same_race
# 0            b'European/Caucasian-American'         0                   2.0  \
# 1            b'European/Caucasian-American'         0                   2.0
# 2  b'Asian/Pacific Islander/Asian-American'         1                   2.0
# ...

# %%
df2 = df[['gender', 'age', 'd_age', 'samerace', 'field', 'attractive_o', 'sinsere_o', 'intelligence_o', 'ambitous_o', 'shared_interests_o', 'funny_o', 'decision_o']].copy()

# %%
df2.dtypes
# Out:
# gender                 object
# age                   float64
# d_age                 float64
# samerace                int64
# field                  object
# attractive_o          float64
# sinsere_o             float64
# intelligence_o        float64
# ambitous_o            float64
# shared_interests_o    float64
# funny_o               float64
# decision_o              int64
# dtype: object

# %%
df2.isnull().sum()
# Out:
# gender                   0
# age                     95
# d_age                    0
# samerace                 0
# field                    0
# attractive_o           212
# sinsere_o              287
# intelligence_o         306
# ambitous_o             722
# shared_interests_o    1076
# funny_o                360
# decision_o               0
# dtype: int64

# %%
df2['attractive_o'].value_counts()[10.5]
# Out:
# 10.0

# %%
df2['field'].unique()
# Out:
# array(["b'Law'", "b'law'", "b'Economics'",
#        "b'Masters in Public Administration'",
#        "b'Masters of Social Work&Education'", "b'Finance'", "b'Business'",
#        "b'political science'", "b'money'", "b'Operations Research'",
#        "b'TC [Health Ed]'", "b'Psychology'", "b'social work'",
#        "b'Social Work'", "b'Speech Language Pathology'",
#        "b'Speech Languahe Pathology'", "b'Educational Psychology'",
#        "b'Applied Maths/Econs'", "b'Mathematics'", "b'Statistics'",
#        "b'Organizational Psychology'", "b'Mechanical Engineering'",
#        "b'Finanace'", "b'Finance&Economics'", "b'Undergrad - GS'",
#        "b'Mathematical Finance'", "b'Medicine'", "b'MBA'", "b'LAW'",
#        "b'?'", "b'psychology'", "b'German Literature'",
#        "b'Business & International Affairs'", "b'MFA Creative Writing'",
#        "b'Engineering'", "b'Electrical Engineering'", "b'Classics'",
#        "b'Operations Research [SEAS]'", "b'chemistry'", "b'Journalism'",
# ...

# %%
df3 = df2[df2['field'] == "b'law'"] 
df3 = df3.dropna(subset=['attractive_o', 'intelligence_o', 'funny_o','ambitous_o', 'shared_interests_o', 'sinsere_o'])

# %%
df3.shape
# Out:
# (105, 12)

# %%
log = LogisticRegression(penalty= None)
x= df3[["d_age",'samerace','attractive_o', 'intelligence_o', 'funny_o','ambitous_o', 'shared_interests_o', 'sinsere_o']].to_numpy()
y= df3["decision_o"].to_numpy()
log.fit(x,y)
# Out:
# LogisticRegression(penalty=None)

# %%
log.predict_proba(x)
# Out:
# array([[0.5777499 , 0.4222501 ],
#        [0.49820647, 0.50179353],
#        [0.04494304, 0.95505696],
#        ...,
#        [0.97788425, 0.02211575],
#        [0.67573269, 0.32426731],
#        [0.27174601, 0.72825399]])

# %%
log.coef_
# Out:
# array([[-0.01783868, -0.01947686,  0.5496946 ,  0.02439948,  0.264757  ,
#         -0.16668203,  0.26889456, -0.10955181]])

# %%
log.intercept_
# Out:
# array([-5.22142736])

# %%
predictions = log.predict(x)

# %%
score = log.score(x, y)
print(score)
# Out:
# 0.7475465794339354
